# %% [markdown]
# ## Connect to News API

# %% [markdown]
# The below code was written by the DSI6 DC team

# %% [markdown]
# Purpose of the code is the connect to and extract headlines from the News API.

# %% [markdown]
# The data from the News API was not used in the final model of the project.

# %%
# !pip install newsapi-python

# %%
#Import Libraries 

import requests
import numpy as np 
import pandas as pd

# %%
url = ('https://newsapi.org/v2/top-headlines?'
       'country=us&'
       'apiKey=9a9406e956094b4497e2b8daaf9e966b')

# %%
response = requests.get(url)

# %%
#check the json file 

print( response.json())
# Out:
# {'status': 'ok', 'totalResults': 38, 'articles': [{'source': {'id': None, 'name': 'Npr.org'}, 'author': '', 'title': 'Police Raided Company Selling $30 Million Of Knock-Off Legos - NPR', 'description': 'In an apparent move to crack down on intellectual property infringement, Chinese authorities raided a company that was allegedly manufacturing and selling $30 million worth of counterfeit Legos.', 'url': 'https://www.npr.org/2019/04/27/717840078/everything-is-not-awesome-for-chinese-company-busted-for-selling-fake-legos', 'urlToImage': 'https://media.npr.org/assets/img/2019/04/27/gettyimages-1037739620_wide-9beecd0d3f37add4e775a1068c1750a21d19bed4.jpg?s=1400', 'publishedAt': '2019-04-27T20:56:00Z', 'content': "The toy company Lepin was raided by Chinese authorities in Shenzhen, China last week for allegedly manufacturing fake Lego products.\r\npicture alliance/picture alliance via Getty Image\r\nA quick visit to the website LepinLand.com and it's pretty clear, the toys… [+2223 chars]"
# ...

# %%
headlines = response.json()

# %%
headlines.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
len(headlines['articles'])
# Out:
# 20

# %%
headlines['articles']
# Out:
# [{'source': {'id': None, 'name': 'Npr.org'},
#   'author': '',
#   'title': 'Police Raided Company Selling $30 Million Of Knock-Off Legos - NPR',
#   'description': 'In an apparent move to crack down on intellectual property infringement, Chinese authorities raided a company that was allegedly manufacturing and selling $30 million worth of counterfeit Legos.',
#   'url': 'https://www.npr.org/2019/04/27/717840078/everything-is-not-awesome-for-chinese-company-busted-for-selling-fake-legos',
#   'urlToImage': 'https://media.npr.org/assets/img/2019/04/27/gettyimages-1037739620_wide-9beecd0d3f37add4e775a1068c1750a21d19bed4.jpg?s=1400',
#   'publishedAt': '2019-04-27T20:56:00Z',
#   'content': "The toy company Lepin was raided by Chinese authorities in Shenzhen, China last week for allegedly manufacturing fake Lego products.\r\npicture alliance/picture alliance via Getty Image\r\nA quick visit to the website LepinLand.com and it's pretty clear, the toys… [+2223 chars]"},
# ...

# %%
practice_pull = pd.DataFrame(headlines['articles'])

# %%
practice_pull
# Out:
#                                   author  \
# 0
# 1                        Madeline Farber
# 2   https://www.10news.com/mario-sevilla
# 3                           Megan Henney
# 4                    Katie Polglase, CNN
# 5                              Adam Shaw
# 6           Jordan Moreau, Jordan Moreau
# 7                             Jon Fingas
# 8                                 CBS/AP
# 9                           Raymond Wong
# 10
# 11                      Jessica Dolcourt
# 12                              Ari Levy
# 13                           BD Williams
# 14                          Megan Henney
# 15                      Andrew Tarantola
# 16
# 17                                  None
# 18                       Safia Samee Ali
# 19                              BBC News
#
#                                               content  \
# 0   The toy company Lepin was raided by Chinese au...
# 1   Marvel fans across the nation are flocking to ...
# ...

# %%
practice_pull['content'][1]
# Out:
# 'Marvel fans across the nation are flocking to theaters this weekend to see “Avengers: Endgame,” but one teacher who won’t be able to see the movie until next week had a strong warning for his students: No spoilers.\r\nIn a viral tweet which had nearly 100,000 r… [+2104 chars]'

# %%
practice_pull['description'][1]
# Out:
# 'Marvel fans across the nation are flocking to theaters this weekend to see “Avengers: Endgame,” but one teacher who won’t be able to see the movie until next week had a strong warning for his students: No spoilers.'

# %%
practice_pull['title'][1]
# Out:
# 'Teacher waiting to see ‘Avengers: Endgame’ warns students not to spoil movie in viral note - Fox News'
